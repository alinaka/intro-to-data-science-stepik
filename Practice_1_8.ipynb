# %%
import pandas as pd
df = pd.DataFrame({'value': [10, 14, 12, 23],
                   'type': ['A', 'A', 'B', 'B']})

# %%
df.head()
# Out:
#    value type
# 0     10    A
# 1     14    A
# 2     12    B
# 3     23    B

# %%
my_stat = pd.read_csv("https://stepik.org/media/attachments/course/4852/my_stat.csv")

# %%
my_stat.head()
# Out:
#    V1    V2 V3   V4
# 0   2  13.0  B  1.0
# 1  -1   7.0  B  1.0
# 2   0  11.0  A  0.0
# 3   2  11.0  A  2.0
# 4   0  10.0  B -1.0

# %%
subset_1 = my_stat.loc[:,['V1', 'V3']].head(10)

# %%
subset_1
# Out:
#    V1 V3
# 0   2  B
# 1  -1  B
# 2   0  A
# 3   2  A
# 4   0  B
# 5   2  A
# 6   0  A
# 7   1  A
# 8   0  B
# 9  -1  A

# %%
subset_2 = my_stat.loc[:,['V2', 'V4']].drop([0, 4])

# %%
subset_2.head()
# Out:
#      V2   V4
# 1   7.0  1.0
# 2  11.0  0.0
# 3  11.0  2.0
# 5  11.0  0.0
# 6   9.0  2.0

# %%
subset_1 = my_stat.loc[(my_stat['V1'] > 0) & (my_stat['V3']=='A')]

# %%
subset_1.head()
# Out:
#     V1    V2 V3   V4
# 3    2  11.0  A  2.0
# 5    2  11.0  A  0.0
# 7    1   9.0  A  1.0
# 10   1  10.0  A  1.0
# 13   1  12.0  A  3.0

# %%
subset_2 = my_stat.query('V2 != 10 | V4 >=1')

# %%
subset_2.head()
# Out:
#    V1    V2 V3   V4
# 0   2  13.0  B  1.0
# 1  -1   7.0  B  1.0
# 2   0  11.0  A  0.0
# 3   2  11.0  A  2.0
# 5   2  11.0  A  0.0

# %%
import numpy as np
my_stat['V5'] = my_stat['V1'] + my_stat['V4']
my_stat.assign(V6=np.log(my_stat.V2))
my_stat.head()
# Out:
#    V1    V2 V3   V4   V5
# 0   2  13.0  B  1.0  3.0
# 1  -1   7.0  B  1.0  0.0
# 2   0  11.0  A  0.0  0.0
# 3   2  11.0  A  2.0  4.0
# 4   0  10.0  B -1.0 -1.0

# %%
my_stat = my_stat.rename(columns={
    'V1': 'session_value',
    'V2': 'group',
    'V3': 'time',
    'V4': 'n_users'
})

# %%
my_stat.head()
# Out:
#    session_value  group time  n_users
# 0              2   13.0    B      1.0
# 1             -1    7.0    B      1.0
# 2              0   11.0    A      0.0
# 3              2   11.0    A      2.0
# 4              0   10.0    B     -1.0

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat_na.csv')

# %%
my_stat_na.tail(10)
# Out:
#      group  n_users  session_value time
# 490    9.0      3.0            0.0    A
# 491    9.0    -18.0           -4.0    B
# 492   10.0    -14.0           -1.0    B
# 493    9.0      3.0           -1.0    B
# 494   10.0     11.0           -1.0    A
# 495   10.0     14.0           -1.0    B
# 496   10.0      6.0           -1.0    A
# 497    7.0     -8.0            0.0    A
# 498   11.0     16.0            0.0    A
# 499   10.0     15.0            0.0    A

# %%
my_query = my_stat.query('n_users >= 0')
median = my_query['n_users'].median()
my_stat = my_stat.fillna(value={
    'session_value': 0,
})
my_stat.loc[my_stat['n_users'] < 0, 'n_users'] = median

# %%
my_query = my_stat.query('n_users >= 0')

# %%
median = my_query['n_users'].median()

# %%
median
# Out:
# 7.0

# %%
my_stat = my_stat.fillna(value={
    'session_value': 0,
})

# %%
my_stat.head()
# Out:
#    group  n_users  session_value time
# 0    9.0     -9.0            1.0    A
# 1   10.0      8.0            2.0    B
# 2   10.0     -1.0            4.0    A
# 3   10.0     -0.0            0.0    B
# 4    9.0    -15.0           -1.0    B

# %%
my_stat.loc[my_stat['n_users'] <= 0, 'n_users'] = median

# %%
my_stat.head()
# Out:
#    group  n_users  session_value time
# 0    9.0      7.0            1.0    A
# 1   10.0      8.0            2.0    B
# 2   10.0      7.0            4.0    A
# 3   10.0      7.0            0.0    B
# 4    9.0      7.0           -1.0    B

# %%
dataframe = my_stat.groupby('group').agg({'session_value': 'mean'})

# %%
dataframe.rename(columns={'session_value': 'mean_session_value_data'}, inplace=True)

# %%
dataframe.head()
# Out:
#        mean_session_value_data
# group
# 7.0                   0.000000
# 8.0                  -0.294118
# 9.0                   0.151786
# 10.0                 -0.047368
# 11.0                  0.112000

# %%
mean_session_value_data = my_stat.groupby('group').agg({'session_value': 'mean'})
mean_session_value_data.rename(columns={'session_value': 'mean_session_value'}, inplace=True)

# %%
mean_session_value_data.head()
# Out:
#        mean_session_value
# group
# 7.0              0.000000
# 8.0             -0.303030
# 9.0              0.160377
# 10.0            -0.048128
# 11.0             0.114754

# %%
mean_session_value_data = my_stat.groupby('group', as_index=False).agg({'session_value': 'mean'})
mean_session_value_data.rename(columns={'session_value': 'mean_session_value'}, inplace=True)

# %%
mean_session_value_data.head()
# Out:
#    group  mean_session_value
# 0    7.0            0.000000
# 1    8.0           -0.303030
# 2    9.0            0.160377
# 3   10.0           -0.048128
# 4   11.0            0.114754
