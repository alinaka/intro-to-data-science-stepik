# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-baf368f80de7> in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
import numpy as np

# %%
StudentsPerformance = pd.read_csv('StudentsPerformance.csv')

# %%
StudentsPerformance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
StudentsPerformance.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
StudentsPerformance.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
StudentsPerformance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
StudentsPerformance.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-daf59184d7e5> in <module>
# ----> 1 StudentsPerformance.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
StudentsPerformance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
StudentsPerformance.shape
# Out:
# (1000, 8)

# %%
StudentsPerformance.groupby('gender').aggregate({'writing_score': 'mean'})
# Out:
# /home/alina/intro-to-data-science-stepik/venv/lib/python3.6/site-packages/pandas/core/groupby/generic.py:1315: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/intro-to-data-science-stepik/venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
StudentsPerformance.groupby('gender').aggregate({'writing score': 'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
StudentsPerformance.size
# Out:
# 8000

# %%
StudentsPerformance.iloc([0:5, 0:3])
# Out:
#   File "<ipython-input-15-d4280d0fb740>", line 1
#     StudentsPerformance.iloc([0:5, 0:3])
#                                ^
# SyntaxError: invalid syntax

# %%
StudentsPerformance.iloc[0:5, 0:3]
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
StudentsPerformance.iloc[[0, 15, 999], [0, 1, -1]]
# Out:
#      gender race/ethnicity  writing score
# 0    female        group B             74
# 15   female        group C             78
# 999  female        group D             86

# %%
StudentsPerformance.iloc[0:7]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
StudentsPerformance.loc[:7]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# ...

# %%
StudentsPerformance.iloc[:7]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
StudentsPerformance.loc['gender']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/intro-to-data-science-stepik/venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'gender'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-188e710e3f0e> in <module>
# ----> 1 StudentsPerformance.loc['gender']
#
# ...

# %%
StudentsPerformance.loc[0:4, 'gender': 'parental level of education']
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
StudentsPerformance.loc[0:4, 'gender':]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
StudentsPerformance.loc[0:4, 'gender']
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
StudentsPerformance.loc[0:4, 'gender', 'math score']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-25-3bb961a219ba> in <module>
# ----> 1 StudentsPerformance.loc[0:4, 'gender', 'math score']
#
# ~/intro-to-data-science-stepik/venv/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# ~/intro-to-data-science-stepik/venv/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     871
#     872         # no multi-index, so validate all of the indexers
# --> 873         self._has_valid_tuple(tup)
#     874
#     875         # ugly hack for GH #836
#
# ...

# %%
StudentsPerformance.loc[0:4, ['gender', 'math score']]
# Out:
#    gender  math score
# 0  female          72
# 1  female          69
# 2  female          90
# 3    male          47
# 4    male          76

# %%
StudentsPerformance.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
StudentsPerformance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
StudentsPerformance.ftypes
# Out:
# gender                         object:dense
# race/ethnicity                 object:dense
# parental level of education    object:dense
# lunch                          object:dense
# test preparation course        object:dense
# math score                      int64:dense
# reading score                   int64:dense
# writing score                   int64:dense
# dtype: object

# %%
StudentsPerformance.shape
# Out:
# (1000, 8)

# %%
StudentsPerformance.size
# Out:
# 8000

# %%
StudentsPerformance.get_dtype_counts()
# Out:
# int64     3
# object    5
# dtype: int64

# %%
StudentsPerformance.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
StudentsPerformance.select_dtypes('gender', 'math score')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-6c18e29995c0> in <module>
# ----> 1 StudentsPerformance.select_dtypes('gender', 'math score')
#
# ~/intro-to-data-science-stepik/venv/lib/python3.6/site-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    3304         # convert the myriad valid dtypes object to a single representation
#    3305         include, exclude = map(
# -> 3306             lambda x: frozenset(map(infer_dtype_from_object, x)), selection)
#    3307         for dtypes in (include, exclude):
#    3308             invalidate_string_dtypes(dtypes)
#
# ~/intro-to-data-science-stepik/venv/lib/python3.6/site-packages/pandas/core/frame.py in <lambda>(x)
#    3304         # convert the myriad valid dtypes object to a single representation
#    3305         include, exclude = map(
# ...

# %%
StudentsPerformance.select_dtypes('int64', 'object')
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# 5            71             83             78
# 6            88             95             92
# 7            40             43             39
# 8            64             64             67
# 9            38             60             50
# 10           58             54             52
# 11           40             52             43
# 12           65             81             73
# 13           78             72             70
# 14           50             53             58
# 15           69             75             78
# 16           88             89             86
# 17           18             32             28
# 18           46             42             46
# ...

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-ac978da59dbd> in <module>
# ----> 1 titanic.read()
#
# ~/intro-to-data-science-stepik/venv/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'read'

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.get_dtype_counts()
# Out:
# float64    2
# int64      5
# object     5
# dtype: int64

# %%
StudentsPerformance.iloc[[0, 3, 4, 7, 8]]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 3                    none          47             57             44
# 4                    none          76             78             75
# 7                    none          40             43             39
# 8               completed          64             64             67

# %%
students_perfomance_with_names = StudentsPerformance.iloc[[0, 3, 4, 7, 8]]

# %%
students_perfomance_with_names
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 3                    none          47             57             44
# 4                    none          76             78             75
# 7                    none          40             43             39
# 8               completed          64             64             67

# %%
students_perfomance_with_names.index = ['Cersei', 'Tywin', 'Gregor', 'Joffrey', 'Ilyn Payne']

# %%
students_perfomance_with_names
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# Cersei      female        group B           bachelor's degree      standard
# Tywin         male        group A          associate's degree  free/reduced
# Gregor        male        group C                some college      standard
# Joffrey       male        group B                some college  free/reduced
# Ilyn Payne    male        group D                 high school  free/reduced
#
#            test preparation course  math score  reading score  writing score
# Cersei                        none          72             72             74
# Tywin                         none          47             57             44
# Gregor                        none          76             78             75
# Joffrey                       none          40             43             39
# Ilyn Payne               completed          64             64             67

# %%
students_perfomance_with_names.index = ['Cersei', 'Tywin', 'Gregor', 'Joffrey']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-e3bde3766dc6> in <module>
# ----> 1 students_perfomance_with_names.index = ['Cersei', 'Tywin', 'Gregor', 'Joffrey']
#
# ~/intro-to-data-science-stepik/venv/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5078         try:
#    5079             object.__getattribute__(self, name)
# -> 5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#    5082             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/intro-to-data-science-stepik/venv/lib/python3.6/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     636
#     637     def _set_axis(self, axis, labels):
# --> 638         self._data.set_axis(axis, labels)
#     639         self._clear_item_cache()
# ...

# %%
students_perfomance_with_names.loc[['Cersei', 'Joffrey']]
# Out:
#          gender race/ethnicity parental level of education         lunch  \
# Cersei   female        group B           bachelor's degree      standard
# Joffrey    male        group B                some college  free/reduced
#
#         test preparation course  math score  reading score  writing score
# Cersei                     none          72             72             74
# Joffrey                    none          40             43             39

# %%
students_perfomance_with_names.loc[['Cersei', 'Joffrey'], ['gender', 'reading score']]
# Out:
#          gender  reading score
# Cersei   female             72
# Joffrey    male             43

# %%
StudentsPerformance.iloc[:, 0]
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
# 5      female
# 6      female
# 7        male
# 8        male
# 9      female
# 10       male
# 11       male
# 12     female
# 13       male
# 14     female
# 15     female
# 16       male
# 17     female
# 18       male
# 19     female
# 20       male
# 21     female
# 22       male
# 23     female
# 24       male
# 25       male
# 26       male
# 27     female
# 28       male
# 29     female
#         ...
# 970    female
# 971      male
# 972    female
# 973    female
# 974    female
# 975    female
# 976      male
# 977      male
# 978      male
# 979    female
# 980    female
# 981      male
# 982      male
# 983    female
# 984    female
# 985      male
# 986    female
# 987      male
# 988    female
# 989    female
# 990      male
# 991    female
# 992    female
# 993    female
# 994      male
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# ...

# %%
students_perfomance_with_names.iloc[:,0]
# Out:
# Cersei        female
# Tywin           male
# Gregor          male
# Joffrey         male
# Ilyn Payne      male
# Name: gender, dtype: object

# %%
type(students_perfomance_with_names.iloc[:,0])
# Out:
# pandas.core.series.Series

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series([1,2,3], index=['Cersei', 'Tywin', 'Gregor'])
# Out:
# Cersei    1
# Tywin     2
# Gregor    3
# dtype: int64

# %%
my_series_1 = pd.Series([1,2,3], index=['Cersei', 'Tywin', 'Gregor'])

# %%
my_series_2 = pd.Series([4,5,6], index=['Cersei', 'Tywin', 'Gregor'])

# %%
pd.DataFrame({'column_name_1': my_series_1, 'column_name_2': my_series_2})
# Out:
#         column_name_1  column_name_2
# Cersei              1              4
# Tywin               2              5
# Gregor              3              6

# %%
students_perfomance_with_names[['gender']]
# Out:
#             gender
# Cersei      female
# Tywin         male
# Gregor        male
# Joffrey       male
# Ilyn Payne    male
