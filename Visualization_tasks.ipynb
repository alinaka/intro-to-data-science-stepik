# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')

# %%
df.head()
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
df['income'].plot()

# %%
df.income.plot()

# %%
df.plot()

# %%
plt.plot(df.index, df.income)

# %%
sns.lineplot(data=df)

# %%
df.plot(kind='line')

# %%
sns.lineplot(x=df.index, y=df.income)

# %%
data = pd.read_csv('dataset_209770_6.txt', sep=" ", header=None)
data.columns = ['x', 'y']

# %%
data.head()
# Out:
#             x           y
# 0  401.539240  911.882898
# 1  506.136736  299.603821
# 2  488.373450  305.800755
# 3  602.749972  396.938401
# 4  593.306414  394.971179

# %%
data.plot.scatter(x='x', y='y')

# %%
data = pd.read_csv('dataset_209770_6.txt', sep=" ", header=None)

# %%
sns.scatterplot(data.iloc[:, 0], data.iloc[:, 1])

# %%
data.head()
# Out:
#             0           1
# 0  401.539240  911.882898
# 1  506.136736  299.603821
# 2  488.373450  305.800755
# 3  602.749972  396.938401
# 4  593.306414  394.971179

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

# %%
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)

# %%
species = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col=0)

# %%
species.head()
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(species, cmap='viridis')
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
dota = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv', index_col=0)

# %%
dota.head()
# Out:
#   attack_type  id  legs  localized_name                          name  \
# 0       Melee   1     2       Anti-Mage        npc_dota_hero_antimage
# 1       Melee   2     2             Axe             npc_dota_hero_axe
# 2      Ranged   3     4            Bane            npc_dota_hero_bane
# 3       Melee   4     2     Bloodseeker     npc_dota_hero_bloodseeker
# 4      Ranged   5     2  Crystal Maiden  npc_dota_hero_crystal_maiden
#
#   primary_attr                                              roles
# 0          agi                       ['Carry', 'Escape', 'Nuker']
# 1          str    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2          int        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3          agi  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4          int        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
dota['count'] = dota.roles.apply(count_roles)

# %%
def count_roles(value):
    return value.count(',')+1

# %%
df= dota['count']

# %%
dota.sort_values('count', ascending=False).head(10)
# Out:
#     attack_type   id  legs localized_name                         name  \
# 71        Melee   73     2      Alchemist      npc_dota_hero_alchemist
# 87        Melee   89     0     Naga Siren     npc_dota_hero_naga_siren
# 18        Melee   19     2           Tiny           npc_dota_hero_tiny
# 15        Melee   16     6      Sand King      npc_dota_hero_sand_king
# 47        Melee   49     2  Dragon Knight  npc_dota_hero_dragon_knight
# 22        Melee   23     2         Kunkka         npc_dota_hero_kunkka
# 80        Melee   82     2          Meepo          npc_dota_hero_meepo
# 114       Melee  120     2      Pangolier      npc_dota_hero_pangolier
# 40        Melee   42     2    Wraith King  npc_dota_hero_skeleton_king
# 25       Ranged   27     2  Shadow Shaman  npc_dota_hero_shadow_shaman
#
#     primary_attr                                              roles  count
# 71           str  ['Carry', 'Support', 'Durable', 'Disabler', 'I...      6
# ...

# %%
df.head()
# Out:
# 0    3
# 1    4
# 2    4
# 3    5
# 4    4
# Name: count, dtype: int64

# %%
sns.distplot(df)

# %%
flowers = pd.read_csv("https://stepik.org/media/attachments/course/4852/iris.csv", index_col=0)

# %%
flowers.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
for column in flowers:
    print(column)
# Out:
# sepal length
# sepal width
# petal length
# petal width
# species

# %%
for column in flowers.loc['sepal length':'petal width']:
    sns.distplot(flowers[column], kde_kws={ "label":column})

# %%
sns.distplot(flowers['sepal length'])

# %%
sns.distplot(flowers['sepal width'])

# %%
sns.distplot(flowers['petal length'])

# %%
sns.distplot(flowers['petal width'])

# %%
 ax = sns.violinplot(y=flowers["petal length"])

# %%
sns.pairplot(flowers)
