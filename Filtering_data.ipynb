# %%
import pandas as pd
import numpy as np

# %%
students_performance = pd.read_csv('StudentsPerformance.csv')

# %%
students_performance.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
# 5      female
# 6      female
# 7        male
# 8        male
# 9      female
# 10       male
# 11       male
# 12     female
# 13       male
# 14     female
# 15     female
# 16       male
# 17     female
# 18       male
# 19     female
# 20       male
# 21     female
# 22       male
# 23     female
# 24       male
# 25       male
# 26       male
# 27     female
# 28       male
# 29     female
#         ...
# 970    female
# 971      male
# 972    female
# 973    female
# 974    female
# 975    female
# 976      male
# 977      male
# 978      male
# 979    female
# 980    female
# 981      male
# 982      male
# 983    female
# 984    female
# 985      male
# 986    female
# 987      male
# 988    female
# 989    female
# 990      male
# 991    female
# 992    female
# 993    female
# 994      male
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# ...

# %%
students_performance.gender == 'female'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
# 5       True
# 6       True
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12      True
# 13     False
# 14      True
# 15      True
# 16     False
# 17      True
# 18     False
# 19      True
# 20     False
# 21      True
# 22     False
# 23      True
# 24     False
# 25     False
# 26     False
# 27      True
# 28     False
# 29      True
#        ...
# 970     True
# 971    False
# 972     True
# 973     True
# 974     True
# 975     True
# 976    False
# 977    False
# 978    False
# 979     True
# 980     True
# 981    False
# 982    False
# 983     True
# 984     True
# 985    False
# 986     True
# 987    False
# 988     True
# 989     True
# 990    False
# 991     True
# 992     True
# 993     True
# 994    False
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
students_performance.loc[students_performance.gender == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 9    female        group B                 high school  free/reduced
# 12   female        group B                 high school      standard
# 14   female        group A             master's degree      standard
# 15   female        group C            some high school      standard
# 17   female        group B            some high school  free/reduced
# 19   female        group C          associate's degree  free/reduced
# 21   female        group B                some college  free/reduced
# 23   female        group C            some high school      standard
# ...

# %%
students_performance.loc[students_performance.gender == 'female', ['gender', 'writing score']]
# Out:
#      gender  writing score
# 0    female             74
# 1    female             88
# 2    female             93
# 5    female             78
# 6    female             92
# 9    female             50
# 12   female             73
# 14   female             58
# 15   female             78
# 17   female             28
# 19   female             61
# 21   female             70
# 23   female             73
# 27   female             75
# 29   female             75
# 30   female             74
# 31   female             61
# 32   female             65
# 36   female             83
# 37   female             59
# 38   female             88
# 41   female             68
# 42   female             65
# 44   female             54
# 46   female             62
# 47   female             76
# 48   female             76
# 54   female             87
# 55   female             43
# 56   female             86
# ..      ...            ...
# 952  female             72
# 954  female             69
# ...

# %%
writing_score = students_performance['writing score'].mean()

# %%
students_performance.loc[students_performance['writing score'] > writing_score]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 12   female        group B                 high school      standard
# 13     male        group A                some college      standard
# 15   female        group C            some high school      standard
# 16     male        group C                 high school      standard
# 21   female        group B                some college  free/reduced
# 23   female        group C            some high school      standard
# 24     male        group D           bachelor's degree  free/reduced
# ...

# %%
students_performance[(students_performance['writing score'] > 60) & students_performance.gender == 'female']
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score]
# Index: []

# %%
students_performance[(students_performance['writing score'] > 60) & (students_performance.gender == 'female')]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 12   female        group B                 high school      standard
# 15   female        group C            some high school      standard
# 19   female        group C          associate's degree  free/reduced
# 21   female        group B                some college  free/reduced
# 23   female        group C            some high school      standard
# 27   female        group C           bachelor's degree      standard
# 29   female        group D             master's degree      standard
# 30   female        group D                some college      standard
# ...

# %%
students_performance.loc[students_performance.lunch == 'free/reduced']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 18     male        group C             master's degree  free/reduced
# 19   female        group C          associate's degree  free/reduced
# 21   female        group B                some college  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# 25     male        group A             master's degree  free/reduced
# 32   female        group E             master's degree  free/reduced
# 37   female        group D            some high school  free/reduced
# 38   female        group D          associate's degree  free/reduced
# ...

# %%
students_performance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
students_performance.loc[students_performance.lunch == 'free/reduced']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 18     male        group C             master's degree  free/reduced
# 19   female        group C          associate's degree  free/reduced
# 21   female        group B                some college  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# 25     male        group A             master's degree  free/reduced
# 32   female        group E             master's degree  free/reduced
# 37   female        group D            some high school  free/reduced
# 38   female        group D          associate's degree  free/reduced
# ...

# %%
free_reduced_lunch = students_performance.loc[students_performance.lunch == 'free/reduced']
writing_score = free_reduced_lunch.mean()

# %%
writing_score
# Out:
# math score       58.921127
# reading score    64.653521
# writing score    63.022535
# dtype: float64

# %%
var = free_reduced_lunch.mean()

# %%
var = free_reduced_lunch.var()

# %%
var
# Out:
# math score       229.824270
# reading score    221.871139
# writing score    238.202881
# dtype: float64

# %%
overall_mean = students_performance.mean()

# %%
overall_mean
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
standard_lunch = students_performance.loc[students_performance.lunch == 'standard']

# %%
standard_lunch.mean()
# Out:
# math score       70.034109
# reading score    71.654264
# writing score    70.823256
# dtype: float64

# %%
standard_lunch.var()
# Out:
# math score       186.418089
# reading score    191.285560
# writing score    205.620887
# dtype: float64

# %%
students_performance.rename(columns={
    'parental level of education': 'parental_level_of_education',
    'test preparation course': 'test_preparation_course',
    'math score': 'math_score',
    'writing score': 'writing_score',
    'reading score': 'reading_score'
})
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
students_performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
students_performance = students_performance.rename(columns={
    'parental level of education': 'parental_level_of_education',
    'test preparation course': 'test_preparation_course',
    'math score': 'math_score',
    'writing score': 'writing_score',
    'reading score': 'reading_score'
})

# %%
students_performance.math_score
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
# 5      71
# 6      88
# 7      40
# 8      64
# 9      38
# 10     58
# 11     40
# 12     65
# 13     78
# 14     50
# 15     69
# 16     88
# 17     18
# 18     46
# 19     54
# 20     66
# 21     65
# 22     44
# 23     69
# 24     74
# 25     73
# 26     69
# 27     67
# 28     70
# 29     62
#        ..
# 970    89
# 971    78
# 972    53
# 973    49
# 974    54
# 975    64
# 976    60
# 977    62
# 978    55
# 979    91
# 980     8
# 981    81
# 982    79
# 983    78
# 984    74
# 985    57
# 986    40
# 987    81
# 988    44
# 989    67
# 990    86
# 991    65
# 992    55
# 993    62
# 994    63
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math_score, Length: 1000, dtype: int64

# %%
students_performance.query("writing_score" > 74)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-d3543fba463f> in <module>
# ----> 1 students_performance.query("writing_score" > 74)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
students_performance.query("writing_score > 74")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 15   female        group C            some high school      standard
# 16     male        group C                 high school      standard
# 24     male        group D           bachelor's degree  free/reduced
# 27   female        group C           bachelor's degree      standard
# 29   female        group D             master's degree      standard
# 34     male        group E                some college      standard
# 35     male        group E          associate's degree      standard
# 36   female        group D          associate's degree      standard
# ...

# %%
students_performance.query("gender == 'female' & writing_score > 74")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 15   female        group C            some high school      standard
# 27   female        group C           bachelor's degree      standard
# 29   female        group D             master's degree      standard
# 36   female        group D          associate's degree      standard
# 38   female        group D          associate's degree  free/reduced
# 47   female        group C                 high school      standard
# 48   female        group D          associate's degree  free/reduced
# 54   female        group C            some high school  free/reduced
# 56   female        group E          associate's degree      standard
# ...

# %%
students_performance.query("gender == 'female' & math_score > 85")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 122  female        group C                some college      standard
# 125  female        group B                 high school      standard
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 229  female        group C                some college      standard
# 263  female        group E                 high school      standard
# 268  female        group D          associate's degree      standard
# 403  female        group D                 high school      standard
# 451  female        group E                some college      standard
# ...

# %%
students_performance.query("gender == 'female' & math_score > 85").size
# Out:
# 296

# %%
students_performance.query("gender == 'female' & math_score > 85").shape
# Out:
# (37, 8)

# %%
students_performance.query("gender == 'male' & math_score > 85").shape
# Out:
# (66, 8)

# %%
math_score_query = 78
students_performance.query("math_score > @math_score_query").shape
# Out:
# (215, 8)

# %%
students_performance[students_performance['parental level of education'].isin(["bachelor's degree", "master's degree"])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/intro-to-data-science-stepik/venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'parental level of education'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-1cb0f8f67b97> in <module>
# ...

# %%
students_performance[students_performance['parental_level_of_education'].isin(["bachelor's degree", "master's degree"])]
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 14   female        group A             master's degree      standard
# 18     male        group C             master's degree  free/reduced
# 24     male        group D           bachelor's degree  free/reduced
# 25     male        group A             master's degree  free/reduced
# 27   female        group C           bachelor's degree      standard
# 29   female        group D             master's degree      standard
# 32   female        group E             master's degree  free/reduced
# 60     male        group E           bachelor's degree  free/reduced
# 77     male        group A           bachelor's degree      standard
# 79   female        group E             master's degree      standard
# 90   female        group C           bachelor's degree      standard
# ...

# %%
students_performance.filter(like='score')
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# 5            71             83             78
# 6            88             95             92
# 7            40             43             39
# 8            64             64             67
# 9            38             60             50
# 10           58             54             52
# 11           40             52             43
# 12           65             81             73
# 13           78             72             70
# 14           50             53             58
# 15           69             75             78
# 16           88             89             86
# 17           18             32             28
# 18           46             42             46
# ...
